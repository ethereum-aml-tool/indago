# %%
import pandas as pd
#C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\transactions-000000000003.csv
sorted = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\processed\transactions-sorted.csv')
unsorted1 = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\transactions-000000000001.csv')
unsorted2 = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\transactions-000000000002.csv')
partially_sorted1 = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\sorted\transactions-000000000001.csv')
partially_sorted2 = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\sorted\transactions-000000000002.csv')

#print(sorted[['block_number','transaction_index']][0:100])
#for i in range(100):
#    print(unsorted[['block_number','transaction_index']].loc[i])
#unsorted1[['block_number','transaction_index']][100:150]

#print(unsorted1[['block_number','transaction_index']][2588:2596]) #[2588:2596]
#print(partially_sorted1[['block_number','transaction_index']][2588:2596])

print(partially_sorted1[['block_number','transaction_index']][2588:2596])
print(partially_sorted2[['block_number','transaction_index']][1038:1048])
# Out:
#       block_number  transaction_index
# 2588      14560409                  5
# 2589      14560409                 19
# 2590      14560409                 34
# 2591      14560409                 36
# 2592      14560409                 37
# 2593      14560409                 51
#       block_number  transaction_index
# 1038      14560408                 20
# 1039      14560408                 79
# 1040      14560408                 95
# 1041      14560408                113
# 1042      14560408                135
# 1043      14560408                140
# 1044      14560409                 42
# 1045      14560409                 71
# 1046      14560409                 86

# %%
sorted = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\processed\transactions-sorted.csv')
sorted_copy = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\processed\transactions-sorted.csv')

sorted.sort_values(by=['block_number','transaction_index'], ascending=True, inplace=True)
sorted.reset_index(inplace=True)
sorted.drop("index", axis=1, inplace=True)
#sorted['from_address'] = sorted['from_address'].fillna("block_reward")
#sorted["value"] = sorted['value'].map(lambda value: int(value))
a = 0
for i in range(len(sorted)):
    if sorted.transaction_index.iloc[i] != sorted_copy.transaction_index.iloc[i]:
        print(i)
        print(sorted.transaction_index.iloc[i])
        print(sorted_copy.transaction_index.iloc[i])
        a += 1
print("number of different: " + str(a))
# Out:
# oh no
# 47369
# 98
# 160
# oh no
# 47370
# 112
# 98
# oh no
# 47371
# 145
# 112
# oh no
# 47372
# 160
# 145
# oh no
# 47380
# 104
# 110
# oh no
# 47381
# 110
# 104
# oh no
# 47386
# 52
# 105
# oh no
# 47387
# 105
# 115
# oh no
# 47388
# 115
# 121
# oh no
# 47389
# 121
# 140
# oh no
# 47390
# 140
# 52
# oh no
# 47411
# 8
# 13
# oh no
# 47412
# 13
# 8
# oh no
# 47414
# 8
# 11
# oh no
# 47415
# 11
# 12
# oh no
# 47416
# 12
# 28
# oh no
# 47417
# 18
# 37
# oh no
# 47418
# 28
# 38
# oh no
# 47419
# 37
# 8
# oh no
# 47420
# 38
# 18
# oh no
# 47424
# 55
# 73
# oh no
# 47425
# 73
# 79
# oh no
# 47426
# 79
# 81
# oh no
# 47427
# 81
# 87
# oh no
# 47428
# 87
# 96
# oh no
# 47429
# 96
# 97
# oh no
# 47430
# 97
# 163
# oh no
# 47431
# 120
# 219
# oh no
# 47432
# 163
# 285
# oh no
# 47433
# 219
# 308
# oh no
# 47434
# 285
# 55
# oh no
# 47435
# 308
# 120
# oh no
# 47454
# 185
# 186
# oh no
# 47455
# 186
# 188
# oh no
# 47456
# 188
# 191
# oh no
# 47457
# 191
# 203
# oh no
# 47458
# 203
# 215
# ...

# %%
sorted = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\processed\transactions-sorted.csv')
a = 0
for i in range(len(sorted)-1):
    if (sorted.block_number.iloc[i] == sorted.block_number.iloc[i+1]):
        if sorted.transaction_index.iloc[i] > sorted.transaction_index.iloc[i+1]:
            print(i)
            print(sorted.transaction_index.iloc[i])
            print(sorted_copy.transaction_index.iloc[i])
            a += 1
print("number of wrongly ordered stuffs: " + str(a))
# Out:
# 47369
# 160
# 160
# 47380
# 110
# 110
# 47389
# 140
# 140
# 47411
# 13
# 13
# 47418
# 38
# 38
# 47433
# 308
# 308
# 47461
# 233
# 233
# 47468
# 206
# 206
# 47483
# 177
# 177
# 47491
# 72
# 72
# 47501
# 297
# 297
# 47523
# 280
# 280
# 47535
# 96
# 96
# 47561
# 367
# 367
# 47585
# 292
# 292
# 47599
# 56
# 56
# 47604
# 58
# 58
# 47613
# 231
# 231
# 47626
# 174
# 174
# 47646
# 304
# 304
# 47675
# 306
# 306
# 47685
# 216
# 216
# 47698
# 173
# 173
# 47725
# 120
# 120
# 47744
# 241
# 241
# 47755
# 112
# 112
# 47763
# 263
# 263
# 47809
# 347
# 347
# 47825
# 133
# 133
# 47854
# 408
# 408
# 47877
# 410
# 410
# 47895
# 180
# 180
# 47899
# 193
# 193
# 47930
# 132
# 132
# 47935
# 134
# 134
# 47947
# 105
# 105
# 47954
# 125
# 125
# 47964
# 63
# 63
# 47970
# 35
# 35
# 47972
# 26
# 26
# 47978
# 50
# 50
# 48001
# 280
# 280
# 48015
# 278
# 278
# 48022
# 285
# 285
# 48082
# 240
# 240
# 48089
# 243
# 243
# 48091
# 161
# 161
# 48106
# 226
# 226
# 48121
# 71
# 71
# 48122
# 27
# 27
# 48136
# 86
# 86
# ...

# %%
sorted = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\sorted\transactions-000000000009.csv')
a = 0
for i in range(len(sorted)-1):
    if (sorted.block_number.iloc[i] == sorted.block_number.iloc[i+1]):
        if sorted.transaction_index.iloc[i] > sorted.transaction_index.iloc[i+1]:
            print(i)
            print(sorted.transaction_index.iloc[i])
            print(sorted_copy.transaction_index.iloc[i])
            a += 1
print("number of wrongly ordered stuffs: " + str(a))
# Out:
# number of wrongly ordered stuffs: 0

# %%
sorted[47365:47375]
# copy head: 1970763
# Out:
#                                                     hash    nonce  \
# 47365  0x57eb15ad2eb304e60dd5e3042d847db16c5876289fba...     2135
# 47366  0x92f2f9c8cea819003174e56808075f2d2270e5c687e3...     1325
# 47367  0x42f78cb780c0bc5816cf14ef6b5f457e036ef619bd14...       15
# 47368  0xc1a8e16515b40c947e074a73586d1e97759ba326d794...        0
# 47369  0x054a488b8c5b817a201514b64d2e07572af5ed17c64d...  3716086
# 47370  0x34a9bd0fe629029460dfc9309c29b275e6cd8b8291ff...       61
# 47371  0x153152354badcd35cef37d6838b0c1a55bf35c2db909...       33
# 47372  0xfacb0a5a113b4c7ecb37bfd6c75c932e38fb38f5e494...  3862441
# 47373  0xabfbbcb7aa1e4965b2a4b860d63b1e65eab96a4c8282...  3862448
# 47374  0xc0d53240735911e4682f47c3ab82ac5655cc069cac0e...        2
#
#        transaction_index                                from_address  \
# 47365                124  0x2fefd2c767d20958a6bbb9f6973a0fb6f64504c4
# 47366                  3  0x54b4f0b9783de6d544db9f835d250a886d42d28b
# ...

# %%
sorted_copy[47365:47375]
# Out:
#                                                     hash    nonce  \
# 47365  0x57eb15ad2eb304e60dd5e3042d847db16c5876289fba...     2135
# 47366  0x92f2f9c8cea819003174e56808075f2d2270e5c687e3...     1325
# 47367  0x42f78cb780c0bc5816cf14ef6b5f457e036ef619bd14...       15
# 47368  0xc1a8e16515b40c947e074a73586d1e97759ba326d794...        0
# 47369  0xfacb0a5a113b4c7ecb37bfd6c75c932e38fb38f5e494...  3862441
# 47370  0x054a488b8c5b817a201514b64d2e07572af5ed17c64d...  3716086
# 47371  0x34a9bd0fe629029460dfc9309c29b275e6cd8b8291ff...       61
# 47372  0x153152354badcd35cef37d6838b0c1a55bf35c2db909...       33
# 47373  0xabfbbcb7aa1e4965b2a4b860d63b1e65eab96a4c8282...  3862448
# 47374  0xc0d53240735911e4682f47c3ab82ac5655cc069cac0e...        2
#
#        transaction_index                                from_address  \
# 47365                124  0x2fefd2c767d20958a6bbb9f6973a0fb6f64504c4
# 47366                  3  0x54b4f0b9783de6d544db9f835d250a886d42d28b
# ...

# %%
not_sorted_0 = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\sorted\transactions-000000000009.csv')
#0xfacb0a5a113b4c7ecb37bfd6c75c932e38fb38f5e494
#0xfacb0a5a113b4c7ecb37bfd6c75c932e38fb38f5e494
not_sorted_0.head()
# Out:
#                                                 hash     nonce  \
# 0  0x077ded1aa6887aa873c7187364cda18b5c225a0515ad...      4221
# 1  0x42f78cb780c0bc5816cf14ef6b5f457e036ef619bd14...        15
# 2  0xc1a8e16515b40c947e074a73586d1e97759ba326d794...         0
# 3  0xfacb0a5a113b4c7ecb37bfd6c75c932e38fb38f5e494...   3862441
# 4  0xeba4acdc464cd456965d3860909b50a3d83f10483792...  42008957
#
#    transaction_index                                from_address  \
# 0                 49  0x1e82e222564293e3507c2966b27f587ee2570671
# 1                 54  0x132a26c12e77450d3ae2dbfb158d6b3614a176aa
# 2                 62  0xe156ae362bd7f9457c6427aef72d8abc345cd8a6
# 3                160  0x00192fb10df37c9fb26829eb2cc623cd1bf599e8
# 4                  2  0xea674fdde714fd979de3edf0f56aa9716b898ec8
#
#                                    to_address                  value     gas  \
# 0  0x93f5813b47f02157cf53b3a294746c95f6098948                      0   46725
# ...

# %%
print(len(sorted_copy))#[11800:11802]
print(len(sorted))
# Out:
# 59015
# 59015

# %%
for i in range(len(sorted_copy)-1):
    if sorted_copy.block_number.iloc[i] == sorted_copy.block_number.iloc[i+1] and sorted_copy.transaction_index.iloc[i] >sorted_copy.transaction_index.iloc[i+1]:
        a = 5

# %%
sorted = pd.read_csv(r'C:\Users\maxar\OneDrive\Documents\Chalmers\ExJobb\Git\Blacklisting\notebooks\data\transactions\processed\transactions-sorted.csv')
 
sorted.transaction_index.head()
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# Name: transaction_index, dtype: int64

# %%
df = pd.DataFrame([-5, -4, 5, 4, 454, 43, 45, -5],columns=["data"])

df: pd.DataFrame = df.sort_values(by="data", ascending=True)
print(df)
# Out:
#    data
# 0    -5
# 7    -5
# 1    -4
# 3     4
# 2     5
# 5    43
# 6    45
# 4   454

# %%
type(sorted.transaction_index.iloc[0])
# Out:
# numpy.int64

# %%
for i in range(len(sorted)):
    a = sorted.transaction_index.iloc[i]
    if a is None:
        print(i)
